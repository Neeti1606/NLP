# %%
import nltk
from nltk.corpus import reuters

# %%
reuters.fileids()
# Out:
# ['test/14826',
#  'test/14828',
#  'test/14829',
#  'test/14832',
#  'test/14833',
#  'test/14839',
#  'test/14840',
#  'test/14841',
#  'test/14842',
#  'test/14843',
#  'test/14844',
#  'test/14849',
#  'test/14852',
#  'test/14854',
#  'test/14858',
#  'test/14859',
#  'test/14860',
#  'test/14861',
#  'test/14862',
#  'test/14863',
#  'test/14865',
#  'test/14867',
#  'test/14872',
#  'test/14873',
#  'test/14875',
#  'test/14876',
#  'test/14877',
#  'test/14881',
#  'test/14882',
#  'test/14885',
#  'test/14886',
#  'test/14888',
#  'test/14890',
#  'test/14891',
#  'test/14892',
#  'test/14899',
#  'test/14900',
#  'test/14903',
#  'test/14904',
#  'test/14907',
#  'test/14909',
#  'test/14911',
#  'test/14912',
#  'test/14913',
#  'test/14918',
#  'test/14919',
#  'test/14921',
#  'test/14922',
#  'test/14923',
#  'test/14926',
#  'test/14928',
#  'test/14930',
#  'test/14931',
#  'test/14932',
#  'test/14933',
#  'test/14934',
#  'test/14941',
#  'test/14943',
#  'test/14949',
#  'test/14951',
#  'test/14954',
#  'test/14957',
#  'test/14958',
#  'test/14959',
#  'test/14960',
#  'test/14962',
#  'test/14963',
#  'test/14964',
#  'test/14965',
#  'test/14967',
#  'test/14968',
#  'test/14969',
#  'test/14970',
#  'test/14971',
#  'test/14974',
#  'test/14975',
#  'test/14978',
#  'test/14981',
#  'test/14982',
#  'test/14983',
#  'test/14984',
#  'test/14985',
#  'test/14986',
#  'test/14987',
#  'test/14988',
#  'test/14993',
#  'test/14995',
#  'test/14998',
#  'test/15000',
#  'test/15001',
#  'test/15002',
#  'test/15004',
#  'test/15005',
#  'test/15006',
#  'test/15011',
#  'test/15012',
#  'test/15013',
#  'test/15016',
#  'test/15017',
#  'test/15020',
#  'test/15023',
#  'test/15024',
#  'test/15026',
#  'test/15027',
#  'test/15028',
#  'test/15029',
#  'test/15031',
#  'test/15032',
#  'test/15033',
#  'test/15037',
#  'test/15038',
#  'test/15043',
#  'test/15045',
#  'test/15046',
#  'test/15048',
#  'test/15049',
#  'test/15052',
#  'test/15053',
#  'test/15055',
#  'test/15056',
#  'test/15060',
#  'test/15061',
#  'test/15062',
#  'test/15063',
#  'test/15065',
#  'test/15067',
#  'test/15069',
#  'test/15070',
#  'test/15074',
#  'test/15077',
#  'test/15078',
#  'test/15079',
#  'test/15082',
#  'test/15090',
#  'test/15091',
#  'test/15092',
#  'test/15093',
#  'test/15094',
#  'test/15095',
#  'test/15096',
#  'test/15097',
#  'test/15103',
#  'test/15104',
#  'test/15106',
#  'test/15107',
#  'test/15109',
#  'test/15110',
#  'test/15111',
#  'test/15112',
#  'test/15118',
#  'test/15119',
#  'test/15120',
#  'test/15121',
#  'test/15122',
#  'test/15124',
#  'test/15126',
#  'test/15128',
#  'test/15129',
#  'test/15130',
#  'test/15132',
#  'test/15136',
#  'test/15138',
#  'test/15141',
#  'test/15144',
#  'test/15145',
#  'test/15146',
#  'test/15149',
#  'test/15152',
#  'test/15153',
#  'test/15154',
#  'test/15156',
#  'test/15157',
#  'test/15161',
#  'test/15162',
#  'test/15171',
#  'test/15172',
#  'test/15175',
#  'test/15179',
#  'test/15180',
#  'test/15185',
#  'test/15188',
#  'test/15189',
#  'test/15190',
#  'test/15193',
#  'test/15194',
#  'test/15197',
#  'test/15198',
#  'test/15200',
#  'test/15204',
#  'test/15205',
#  'test/15206',
#  'test/15207',
#  'test/15208',
#  'test/15210',
#  'test/15211',
#  'test/15212',
#  'test/15213',
#  'test/15217',
#  'test/15219',
#  'test/15220',
#  'test/15221',
#  'test/15222',
#  'test/15223',
#  'test/15226',
#  'test/15227',
#  'test/15230',
#  'test/15233',
#  'test/15234',
#  'test/15237',
#  'test/15238',
#  'test/15239',
#  'test/15240',
#  'test/15242',
#  'test/15243',
#  'test/15244',
#  'test/15246',
#  'test/15247',
#  'test/15250',
#  'test/15253',
#  'test/15254',
#  'test/15255',
#  'test/15258',
#  'test/15259',
#  'test/15262',
#  'test/15263',
#  'test/15264',
#  'test/15265',
#  'test/15270',
#  'test/15271',
#  'test/15273',
#  'test/15274',
#  'test/15276',
#  'test/15278',
#  'test/15280',
#  'test/15281',
#  'test/15283',
#  'test/15287',
#  'test/15290',
#  'test/15292',
#  'test/15294',
#  'test/15295',
#  'test/15296',
#  'test/15299',
#  'test/15300',
#  'test/15302',
#  'test/15303',
#  'test/15306',
#  'test/15307',
#  'test/15308',
#  'test/15309',
#  'test/15310',
#  'test/15311',
#  'test/15312',
#  'test/15313',
#  'test/15314',
#  'test/15315',
#  'test/15321',
#  'test/15322',
#  'test/15324',
#  'test/15325',
#  'test/15326',
#  'test/15327',
#  'test/15329',
#  'test/15335',
#  'test/15336',
#  'test/15337',
#  'test/15339',
#  'test/15341',
#  'test/15344',
#  'test/15345',
#  'test/15348',
#  'test/15349',
#  'test/15351',
#  'test/15352',
#  'test/15354',
#  'test/15356',
#  'test/15357',
#  'test/15359',
#  'test/15363',
#  'test/15364',
#  'test/15365',
#  'test/15366',
#  'test/15367',
#  'test/15368',
#  'test/15372',
#  'test/15375',
#  'test/15378',
#  'test/15379',
#  'test/15380',
#  'test/15383',
#  'test/15384',
#  'test/15386',
#  'test/15387',
#  'test/15388',
#  'test/15389',
#  'test/15391',
#  'test/15394',
#  'test/15396',
#  'test/15397',
#  'test/15400',
#  'test/15404',
#  'test/15406',
#  'test/15409',
#  'test/15410',
#  'test/15411',
#  'test/15413',
#  'test/15415',
#  'test/15416',
#  'test/15417',
#  'test/15420',
#  'test/15421',
#  'test/15424',
#  'test/15425',
#  'test/15427',
#  'test/15428',
#  'test/15429',
#  'test/15430',
#  'test/15431',
#  'test/15432',
#  'test/15436',
#  'test/15438',
#  'test/15441',
#  'test/15442',
#  'test/15444',
#  'test/15446',
#  'test/15447',
#  'test/15448',
#  'test/15449',
#  'test/15450',
#  'test/15451',
#  'test/15452',
#  'test/15453',
#  'test/15454',
#  'test/15455',
#  'test/15457',
#  'test/15459',
#  'test/15460',
#  'test/15462',
#  'test/15464',
#  'test/15467',
#  'test/15468',
#  'test/15471',
#  'test/15472',
#  'test/15476',
#  'test/15477',
#  'test/15478',
#  'test/15479',
#  'test/15481',
#  'test/15482',
#  'test/15483',
#  'test/15484',
#  'test/15485',
#  'test/15487',
#  'test/15489',
#  'test/15494',
#  'test/15495',
#  'test/15496',
#  'test/15500',
#  'test/15501',
#  'test/15503',
#  'test/15504',
#  'test/15510',
#  'test/15511',
#  'test/15515',
#  'test/15520',
#  'test/15521',
#  'test/15522',
#  'test/15523',
#  'test/15527',
#  'test/15528',
#  'test/15531',
#  'test/15532',
#  'test/15535',
#  'test/15536',
#  'test/15539',
#  'test/15540',
#  'test/15542',
#  'test/15543',
#  'test/15544',
#  'test/15545',
#  'test/15547',
#  'test/15548',
#  'test/15549',
#  'test/15550',
#  'test/15551',
#  'test/15552',
#  'test/15553',
#  'test/15556',
#  'test/15558',
#  'test/15559',
#  'test/15560',
#  'test/15561',
#  'test/15562',
#  'test/15563',
#  'test/15565',
#  'test/15566',
#  'test/15567',
#  'test/15568',
#  'test/15569',
#  'test/15570',
#  'test/15571',
#  'test/15572',
#  'test/15573',
#  'test/15574',
#  'test/15575',
#  'test/15578',
#  'test/15579',
#  'test/15580',
#  'test/15581',
#  'test/15582',
#  'test/15583',
#  'test/15584',
#  'test/15585',
#  'test/15590',
#  'test/15591',
#  'test/15593',
#  'test/15594',
#  'test/15595',
#  'test/15596',
#  'test/15597',
#  'test/15598',
#  'test/15600',
#  'test/15601',
#  'test/15602',
#  'test/15603',
#  'test/15605',
#  'test/15607',
#  'test/15610',
#  'test/15613',
#  'test/15615',
#  'test/15616',
#  'test/15617',
#  'test/15618',
#  'test/15620',
#  'test/15621',
#  'test/15623',
#  'test/15624',
#  'test/15625',
#  'test/15626',
#  'test/15629',
#  'test/15632',
#  'test/15634',
#  'test/15636',
#  'test/15637',
#  'test/15639',
#  'test/15640',
#  'test/15641',
#  'test/15642',
#  'test/15643',
#  'test/15646',
#  'test/15648',
#  'test/15649',
#  'test/15651',
#  'test/15653',
#  'test/15655',
#  'test/15656',
#  'test/15664',
#  'test/15666',
#  'test/15667',
#  'test/15668',
#  'test/15669',
#  'test/15672',
#  'test/15674',
#  'test/15675',
#  'test/15676',
#  'test/15677',
#  'test/15679',
#  'test/15680',
#  'test/15682',
#  'test/15686',
#  'test/15688',
#  'test/15689',
#  'test/15691',
#  'test/15692',
#  'test/15694',
#  'test/15695',
#  'test/15696',
#  'test/15698',
#  'test/15702',
#  'test/15703',
#  'test/15704',
#  'test/15707',
#  'test/15708',
#  'test/15709',
#  'test/15710',
#  'test/15713',
#  'test/15715',
#  'test/15717',
#  'test/15719',
#  'test/15720',
#  'test/15721',
#  'test/15723',
#  'test/15725',
#  'test/15726',
#  'test/15727',
#  'test/15728',
#  'test/15729',
#  'test/15732',
#  'test/15733',
#  'test/15736',
#  'test/15737',
#  'test/15739',
#  'test/15742',
#  'test/15749',
#  'test/15751',
#  'test/15753',
#  'test/15757',
#  'test/15759',
#  'test/15762',
#  'test/15767',
#  'test/15768',
#  'test/15769',
#  'test/15772',
#  'test/15777',
#  'test/15778',
#  'test/15780',
#  'test/15782',
#  'test/15785',
#  'test/15790',
#  'test/15793',
#  'test/15797',
#  'test/15798',
#  'test/15800',
#  'test/15801',
#  'test/15803',
#  'test/15804',
#  'test/15805',
#  'test/15807',
#  'test/15808',
#  'test/15810',
#  'test/15811',
#  'test/15816',
#  'test/15817',
#  'test/15819',
#  'test/15821',
#  'test/15822',
#  'test/15823',
#  'test/15829',
#  'test/15831',
#  'test/15832',
#  'test/15833',
#  'test/15834',
#  'test/15836',
#  'test/15838',
#  'test/15840',
#  'test/15841',
#  'test/15842',
#  'test/15844',
#  'test/15845',
#  'test/15846',
#  'test/15847',
#  'test/15851',
#  'test/15852',
#  'test/15853',
#  'test/15854',
#  'test/15855',
#  'test/15856',
#  'test/15858',
#  'test/15859',
#  'test/15860',
#  'test/15861',
#  'test/15863',
#  'test/15864',
#  'test/15865',
#  'test/15866',
#  'test/15867',
#  'test/15868',
#  'test/15869',
#  'test/15870',
#  'test/15871',
#  'test/15872',
#  'test/15874',
#  'test/15875',
#  'test/15876',
#  'test/15877',
#  'test/15878',
#  'test/15879',
#  'test/15881',
#  'test/15885',
#  'test/15886',
#  'test/15888',
#  'test/15889',
#  'test/15890',
#  'test/15892',
#  'test/15893',
#  'test/15894',
#  'test/15895',
#  'test/15896',
#  'test/15897',
#  'test/15898',
#  'test/15899',
#  'test/15900',
#  'test/15901',
#  'test/15902',
#  'test/15903',
#  'test/15904',
#  'test/15906',
#  'test/15908',
#  'test/15909',
#  'test/15910',
#  'test/15911',
#  'test/15912',
#  'test/15913',
#  'test/15914',
#  'test/15916',
#  'test/15917',
#  'test/15918',
#  'test/15920',
#  'test/15921',
#  'test/15922',
#  'test/15923',
#  'test/15924',
#  'test/15925',
#  'test/15927',
#  'test/15928',
#  'test/15929',
#  'test/15930',
#  'test/15932',
#  'test/15933',
#  'test/15934',
#  'test/15937',
#  'test/15939',
#  'test/15942',
#  'test/15944',
#  'test/15949',
#  'test/15950',
#  'test/15951',
#  'test/15952',
#  'test/15953',
#  'test/15956',
#  'test/15959',
#  'test/15960',
#  'test/15961',
#  'test/15963',
#  'test/15964',
#  'test/15967',
#  'test/15968',
#  'test/15969',
#  'test/15970',
#  'test/15973',
#  'test/15975',
#  'test/15976',
#  'test/15977',
#  'test/15978',
#  'test/15979',
#  'test/15980',
#  'test/15981',
#  'test/15984',
#  'test/15985',
#  'test/15987',
#  'test/15988',
#  'test/15989',
#  'test/15993',
#  'test/15995',
#  'test/15996',
#  'test/15997',
#  'test/15999',
#  'test/16002',
#  'test/16003',
#  'test/16004',
#  'test/16005',
#  'test/16006',
#  'test/16007',
#  'test/16009',
#  'test/16012',
#  'test/16013',
#  'test/16014',
#  'test/16015',
#  'test/16016',
#  'test/16021',
#  'test/16022',
#  'test/16023',
#  'test/16026',
#  'test/16029',
#  'test/16030',
#  'test/16033',
#  'test/16037',
#  'test/16040',
#  'test/16041',
#  'test/16045',
#  'test/16052',
#  'test/16053',
#  'test/16055',
#  'test/16063',
#  'test/16066',
#  'test/16067',
#  'test/16068',
#  'test/16069',
#  'test/16071',
#  'test/16072',
#  'test/16074',
#  'test/16075',
#  'test/16076',
#  'test/16077',
#  'test/16079',
#  'test/16080',
#  'test/16083',
#  'test/16086',
#  'test/16088',
#  'test/16091',
#  'test/16093',
#  'test/16094',
#  'test/16095',
#  'test/16096',
#  'test/16097',
#  'test/16098',
#  'test/16099',
#  'test/16100',
#  'test/16103',
#  'test/16106',
#  'test/16107',
#  'test/16108',
#  'test/16110',
#  'test/16111',
#  'test/16112',
#  'test/16115',
#  'test/16117',
#  'test/16118',
#  'test/16119',
#  'test/16120',
#  'test/16122',
#  'test/16123',
#  'test/16125',
#  'test/16126',
#  'test/16130',
#  'test/16133',
#  'test/16134',
#  'test/16136',
#  'test/16139',
#  'test/16140',
#  'test/16141',
#  'test/16142',
#  'test/16143',
#  'test/16144',
#  'test/16145',
#  'test/16146',
#  'test/16147',
#  'test/16148',
#  'test/16149',
#  'test/16150',
#  'test/16152',
#  'test/16155',
#  'test/16158',
#  'test/16159',
#  'test/16161',
#  'test/16162',
#  'test/16163',
#  'test/16164',
#  'test/16166',
#  'test/16170',
#  'test/16171',
#  'test/16172',
#  'test/16173',
#  'test/16175',
#  'test/16176',
#  'test/16177',
#  'test/16179',
#  'test/16180',
#  'test/16185',
#  'test/16188',
#  'test/16189',
#  'test/16190',
#  'test/16193',
#  'test/16194',
#  'test/16195',
#  'test/16196',
#  'test/16197',
#  'test/16200',
#  'test/16201',
#  'test/16202',
#  'test/16203',
#  'test/16206',
#  'test/16207',
#  'test/16210',
#  'test/16211',
#  'test/16212',
#  'test/16213',
#  'test/16214',
#  'test/16215',
#  'test/16216',
#  'test/16219',
#  'test/16221',
#  'test/16223',
#  'test/16225',
#  'test/16226',
#  'test/16228',
#  'test/16230',
#  'test/16232',
#  'test/16233',
#  'test/16234',
#  'test/16236',
#  'test/16238',
#  'test/16241',
#  'test/16243',
#  'test/16244',
#  'test/16246',
#  'test/16247',
#  'test/16248',
#  'test/16250',
#  'test/16251',
#  'test/16252',
#  'test/16255',
#  'test/16256',
#  'test/16257',
#  'test/16258',
#  'test/16260',
#  'test/16262',
#  'test/16263',
#  'test/16264',
#  'test/16265',
#  'test/16266',
#  'test/16268',
#  'test/16269',
#  'test/16270',
#  'test/16271',
#  'test/16274',
#  'test/16275',
#  'test/16277',
#  'test/16278',
#  'test/16279',
#  'test/16281',
#  'test/16282',
#  'test/16283',
#  'test/16284',
#  'test/16285',
#  'test/16286',
#  'test/16287',
#  'test/16288',
#  'test/16289',
#  'test/16291',
#  'test/16294',
#  'test/16297',
#  'test/16298',
#  'test/16299',
#  'test/16300',
#  'test/16301',
#  'test/16302',
#  'test/16303',
#  'test/16304',
#  'test/16307',
#  'test/16310',
#  'test/16311',
#  'test/16312',
#  'test/16314',
#  'test/16315',
#  'test/16316',
#  'test/16317',
#  'test/16318',
#  'test/16319',
#  'test/16320',
#  'test/16324',
#  'test/16327',
#  'test/16331',
#  'test/16332',
#  'test/16336',
#  'test/16337',
#  'test/16339',
#  'test/16342',
#  'test/16343',
#  'test/16346',
#  'test/16347',
#  'test/16348',
#  'test/16350',
#  'test/16354',
#  'test/16357',
#  'test/16359',
#  'test/16360',
#  'test/16362',
#  'test/16363',
#  'test/16365',
#  'test/16366',
#  'test/16367',
#  'test/16369',
#  'test/16370',
#  'test/16371',
#  'test/16372',
#  'test/16374',
#  'test/16376',
#  'test/16377',
#  'test/16379',
#  'test/16380',
#  'test/16383',
#  'test/16385',
#  'test/16386',
#  'test/16388',
#  'test/16390',
#  'test/16392',
#  'test/16393',
#  'test/16394',
#  'test/16395',
#  'test/16396',
#  'test/16398',
#  'test/16399',
#  'test/16400',
#  'test/16401',
#  'test/16402',
#  'test/16403',
#  'test/16404',
#  'test/16405',
#  'test/16406',
#  'test/16407',
#  'test/16409',
#  'test/16410',
#  'test/16415',
#  'test/16417',
#  'test/16418',
#  'test/16419',
#  'test/16420',
#  'test/16421',
#  'test/16422',
#  'test/16424',
#  'test/16426',
#  'test/16427',
#  'test/16428',
#  'test/16429',
#  'test/16430',
#  'test/16432',
#  'test/16433',
#  'test/16434',
#  'test/16437',
#  'test/16438',
#  'test/16440',
#  'test/16441',
#  'test/16442',
#  'test/16443',
#  'test/16444',
#  'test/16448',
#  'test/16449',
#  'test/16450',
#  'test/16454',
#  'test/16457',
#  'test/16458',
#  'test/16459',
#  'test/16460',
#  'test/16461',
#  'test/16463',
#  'test/16465',
#  'test/16468',
#  'test/16469',
#  'test/16470',
#  'test/16471',
#  'test/16472',
#  'test/16473',
#  'test/16475',
#  'test/16476',
#  'test/16478',
#  'test/16479',
#  'test/16480',
#  'test/16481',
#  'test/16483',
#  'test/16486',
#  'test/16487',
#  'test/16488',
#  'test/16490',
#  'test/16492',
#  'test/16493',
#  'test/16495',
#  'test/16496',
#  'test/16499',
#  'test/16502',
#  'test/16505',
#  'test/16510',
#  'test/16512',
#  'test/16513',
#  'test/16518',
#  'test/16519',
#  'test/16521',
#  'test/16522',
#  'test/16523',
#  'test/16525',
#  'test/16527',
#  'test/16530',
#  'test/16531',
#  'test/16533',
#  'test/16538',
#  'test/16539',
#  'test/16545',
#  'test/16546',
#  'test/16549',
#  'test/16551',
#  'test/16554',
#  'test/16555',
#  'test/16561',
#  'test/16563',
#  'test/16564',
#  'test/16565',
#  'test/16568',
#  'test/16569',
#  'test/16570',
#  'test/16574',
#  'test/16577',
#  'test/16581',
#  'test/16583',
#  'test/16584',
#  'test/16585',
#  'test/16587',
#  'test/16588',
#  'test/16589',
#  'test/16590',
#  'test/16591',
#  ...]

# %%
reuters.categories()
# Out:
# ['acq',
#  'alum',
#  'barley',
#  'bop',
#  'carcass',
#  'castor-oil',
#  'cocoa',
#  'coconut',
#  'coconut-oil',
#  'coffee',
#  'copper',
#  'copra-cake',
#  'corn',
#  'cotton',
#  'cotton-oil',
#  'cpi',
#  'cpu',
#  'crude',
#  'dfl',
#  'dlr',
#  'dmk',
#  'earn',
#  'fuel',
#  'gas',
#  'gnp',
#  'gold',
#  'grain',
#  'groundnut',
#  'groundnut-oil',
#  'heat',
#  'hog',
#  'housing',
#  'income',
#  'instal-debt',
#  'interest',
#  'ipi',
#  'iron-steel',
#  'jet',
#  'jobs',
#  'l-cattle',
#  'lead',
#  'lei',
#  'lin-oil',
#  'livestock',
#  'lumber',
#  'meal-feed',
#  'money-fx',
#  'money-supply',
#  'naphtha',
#  'nat-gas',
#  'nickel',
#  'nkr',
#  'nzdlr',
#  'oat',
#  'oilseed',
#  'orange',
#  'palladium',
#  'palm-oil',
#  'palmkernel',
#  'pet-chem',
#  'platinum',
#  'potato',
#  'propane',
#  'rand',
#  'rape-oil',
#  'rapeseed',
#  'reserves',
#  'retail',
#  'rice',
#  'rubber',
#  'rye',
#  'ship',
#  'silver',
#  'sorghum',
#  'soy-meal',
#  'soy-oil',
#  'soybean',
#  'strategic-metal',
#  'sugar',
#  'sun-meal',
#  'sun-oil',
#  'sunseed',
#  'tea',
#  'tin',
#  'trade',
#  'veg-oil',
#  'wheat',
#  'wpi',
#  'yen',
#  'zinc']

# %%
print(reuters.words())
length= len(reuters.words())
print("Lenght of the corpus ", length)
# Out:
# ['ASIAN', 'EXPORTERS', 'FEAR', 'DAMAGE', 'FROM', 'U', ...]
# Lenght of the corpus  1720901

# %%
reuters.fileids(['wheat','rice'])
# Out:
# ['test/14832',
#  'test/14841',
#  'test/14858',
#  'test/15043',
#  'test/15097',
#  'test/15132',
#  'test/15206',
#  'test/15271',
#  'test/15273',
#  'test/15341',
#  'test/15367',
#  'test/15388',
#  'test/15472',
#  'test/15500',
#  'test/15567',
#  'test/15572',
#  'test/15582',
#  'test/15618',
#  'test/15676',
#  'test/15686',
#  'test/15728',
#  'test/15836',
#  'test/15845',
#  'test/15853',
#  'test/15860',
#  'test/15863',
#  'test/15864',
#  'test/15866',
#  'test/15868',
#  'test/15869',
#  'test/15870',
#  'test/15871',
#  'test/15874',
#  'test/15875',
#  'test/15890',
#  'test/15893',
#  'test/15895',
#  'test/15906',
#  'test/15911',
#  'test/15916',
#  'test/15917',
#  'test/15927',
#  'test/15928',
#  'test/15952',
#  'test/16071',
#  'test/16079',
#  'test/16099',
#  'test/16144',
#  'test/16147',
#  'test/16271',
#  'test/16525',
#  'test/16601',
#  'test/16784',
#  'test/17503',
#  'test/17521',
#  'test/17662',
#  'test/17722',
#  'test/17755',
#  'test/17955',
#  'test/17962',
#  'test/18275',
#  'test/18297',
#  'test/18345',
#  'test/18609',
#  'test/18642',
#  'test/18899',
#  'test/18908',
#  'test/19059',
#  'test/19165',
#  'test/19169',
#  'test/19213',
#  'test/19275',
#  'test/19322',
#  'test/19388',
#  'test/19549',
#  'test/19668',
#  'test/19821',
#  'test/19835',
#  'test/19947',
#  'test/20052',
#  'test/20231',
#  'test/20239',
#  'test/20258',
#  'test/20511',
#  'test/20550',
#  'test/20611',
#  'test/20645',
#  'test/20738',
#  'test/21091',
#  'test/21243',
#  'test/21570',
#  'training/10120',
#  'training/10172',
#  'training/10175',
#  'training/10268',
#  'training/10305',
#  'training/10406',
#  'training/10444',
#  'training/10494',
#  'training/10519',
#  'training/10569',
#  'training/1057',
#  'training/1067',
#  'training/1069',
#  'training/10830',
#  'training/10882',
#  'training/1094',
#  'training/10956',
#  'training/11012',
#  'training/11040',
#  'training/11085',
#  'training/11091',
#  'training/11119',
#  'training/11208',
#  'training/11216',
#  'training/11224',
#  'training/11316',
#  'training/11343',
#  'training/11380',
#  'training/11392',
#  'training/11399',
#  'training/11415',
#  'training/11427',
#  'training/11445',
#  'training/11536',
#  'training/11608',
#  'training/11610',
#  'training/11640',
#  'training/11645',
#  'training/11655',
#  'training/11671',
#  'training/11694',
#  'training/11815',
#  'training/11834',
#  'training/1185',
#  'training/11885',
#  'training/11886',
#  'training/12002',
#  'training/12009',
#  'training/12192',
#  'training/12254',
#  'training/12261',
#  'training/12269',
#  'training/12325',
#  'training/12372',
#  'training/12420',
#  'training/12428',
#  'training/12458',
#  'training/12500',
#  'training/12543',
#  'training/1257',
#  'training/12762',
#  'training/12802',
#  'training/12887',
#  'training/1295',
#  'training/12971',
#  'training/13094',
#  'training/13097',
#  'training/13123',
#  'training/13129',
#  'training/13179',
#  'training/13272',
#  'training/13294',
#  'training/13313',
#  'training/13729',
#  'training/13744',
#  'training/1377',
#  'training/1385',
#  'training/13852',
#  'training/13856',
#  'training/1388',
#  'training/1396',
#  'training/1405',
#  'training/14126',
#  'training/14491',
#  'training/14509',
#  'training/14515',
#  'training/14718',
#  'training/14721',
#  'training/14722',
#  'training/1570',
#  'training/1590',
#  'training/1640',
#  'training/1674',
#  'training/1777',
#  'training/1792',
#  'training/180',
#  'training/1882',
#  'training/19',
#  'training/1901',
#  'training/1907',
#  'training/1915',
#  'training/1970',
#  'training/2003',
#  'training/2008',
#  'training/2044',
#  'training/2074',
#  'training/2095',
#  'training/2169',
#  'training/2172',
#  'training/2191',
#  'training/2217',
#  'training/2223',
#  'training/228',
#  'training/235',
#  'training/2367',
#  'training/2382',
#  'training/241',
#  'training/2425',
#  'training/2508',
#  'training/2524',
#  'training/253',
#  'training/2535',
#  'training/254',
#  'training/2741',
#  'training/2747',
#  'training/2857',
#  'training/2864',
#  'training/3132',
#  'training/3138',
#  'training/3272',
#  'training/3282',
#  'training/3299',
#  'training/3314',
#  'training/3323',
#  'training/3330',
#  'training/3334',
#  'training/3335',
#  'training/3358',
#  'training/3401',
#  'training/3429',
#  'training/3445',
#  'training/3737',
#  'training/3897',
#  'training/3904',
#  'training/3913',
#  'training/395',
#  'training/4057',
#  'training/4077',
#  'training/4133',
#  'training/4203',
#  'training/425',
#  'training/4278',
#  'training/4296',
#  'training/4314',
#  'training/4356',
#  'training/4382',
#  'training/4473',
#  'training/4478',
#  'training/4490',
#  'training/4549',
#  'training/4599',
#  'training/4671',
#  'training/4678',
#  'training/4696',
#  'training/4719',
#  'training/5',
#  'training/501',
#  'training/5056',
#  'training/5266',
#  'training/5383',
#  'training/5467',
#  'training/5531',
#  'training/5606',
#  'training/5610',
#  'training/5636',
#  'training/5639',
#  'training/5648',
#  'training/6',
#  'training/6006',
#  'training/6079',
#  'training/6081',
#  'training/6114',
#  'training/6127',
#  'training/6153',
#  'training/6209',
#  'training/6221',
#  'training/6239',
#  'training/6259',
#  'training/6269',
#  'training/6296',
#  'training/6326',
#  'training/6339',
#  'training/6720',
#  'training/6744',
#  'training/6751',
#  'training/6882',
#  'training/6898',
#  'training/6903',
#  'training/6909',
#  'training/694',
#  'training/6946',
#  'training/6960',
#  'training/7062',
#  'training/7160',
#  'training/7205',
#  'training/7215',
#  'training/7326',
#  'training/742',
#  'training/7471',
#  'training/7545',
#  'training/7917',
#  'training/7934',
#  'training/7957',
#  'training/8003',
#  'training/8161',
#  'training/8179',
#  'training/8273',
#  'training/8413',
#  'training/8535',
#  'training/856',
#  'training/8604',
#  'training/874',
#  'training/8759',
#  'training/8993',
#  'training/9018',
#  'training/9021',
#  'training/9095',
#  'training/97',
#  'training/9705',
#  'training/9773',
#  'training/9782',
#  'training/9793',
#  'training/9865']

# %%
reuters.sents()
# Out:
# [['ASIAN', 'EXPORTERS', 'FEAR', 'DAMAGE', 'FROM', 'U', '.', 'S', '.-', 'JAPAN', 'RIFT', 'Mounting', 'trade', 'friction', 'between', 'the', 'U', '.', 'S', '.', 'And', 'Japan', 'has', 'raised', 'fears', 'among', 'many', 'of', 'Asia', "'", 's', 'exporting', 'nations', 'that', 'the', 'row', 'could', 'inflict', 'far', '-', 'reaching', 'economic', 'damage', ',', 'businessmen', 'and', 'officials', 'said', '.'], ['They', 'told', 'Reuter', 'correspondents', 'in', 'Asian', 'capitals', 'a', 'U', '.', 'S', '.', 'Move', 'against', 'Japan', 'might', 'boost', 'protectionist', 'sentiment', 'in', 'the', 'U', '.', 'S', '.', 'And', 'lead', 'to', 'curbs', 'on', 'American', 'imports', 'of', 'their', 'products', '.'], ...]

# %%
reuters.sents(fileids='test/15500')
# Out:
# [['RPT', '-', 'ARGENTINE', 'GRAIN', '/', 'OILSEED', 'EXPORT', 'PRICES', 'ADJUSTED', 'The', 'Argentine', 'Grain', 'Board', 'adjusted', 'minimum', 'export', 'prices', 'of', 'grain', 'and', 'oilseed', 'products', 'in', 'dlrs', 'per', 'tonne', 'FOB', ',', 'previous', 'in', 'brackets', ',', 'as', 'follows', ':', 'Sorghum', '64', '(', '63', '),', 'sunflowerseed', 'cake', 'and', 'expellers', '103', '(', '102', ')', ',', 'pellets', '101', '(', '100', '),', 'meal', '99', '(', '98', '),', 'linseed', 'oil', '274', '(', '264', '),', 'groundnutseed', 'oil', '450', '(', '445', '),', 'soybean', 'oil', '300', '(', '290', '),', 'rapeseed', 'oil', '290', '(', '280', ').'], ['Sunflowerseed', 'oil', 'for', 'shipment', 'through', 'May', '323', '(', '313', ')', 'and', 'june', 'onwards', '330', '(', '320', ').'], ...]

# %%
len(reuters.fileids())
# Out:
# 10788

# %%
rawtext= reuters.raw('test/15500').strip()[:1000]
print(rawtext)
# Out:
# RPT - ARGENTINE GRAIN/OILSEED EXPORT PRICES ADJUSTED
#   The Argentine Grain Board adjusted
#   minimum export prices of grain and oilseed products in dlrs per
#   tonne FOB, previous in brackets, as follows:
#       Sorghum 64 (63), sunflowerseed cake and expellers 103 (102)
#   , pellets 101 (100), meal 99 (98), linseed oil 274 (264),
#   groundnutseed oil 450 (445), soybean oil 300 (290), rapeseed
#   oil 290 (280).
#       Sunflowerseed oil for shipment through May 323 (313) and
#   june onwards 330 (320).
#       The board also adjusted export prices at which export taxes
#   are levied in dlrs per tonne FOB, previous in brackets, as
#   follows:
#       Bran pollard wheat 40 (42), pellets 42 (44).

# %%
from nltk import sent_tokenize, word_tokenize

# %%
word_tokenize(rawtext)
# Out:
# ['RPT',
#  '-',
#  'ARGENTINE',
#  'GRAIN/OILSEED',
#  'EXPORT',
#  'PRICES',
#  'ADJUSTED',
#  'The',
#  'Argentine',
#  'Grain',
#  'Board',
#  'adjusted',
#  'minimum',
#  'export',
#  'prices',
#  'of',
#  'grain',
#  'and',
#  'oilseed',
#  'products',
#  'in',
#  'dlrs',
#  'per',
#  'tonne',
#  'FOB',
#  ',',
#  'previous',
#  'in',
#  'brackets',
#  ',',
#  'as',
#  'follows',
#  ':',
#  'Sorghum',
#  '64',
#  '(',
#  '63',
#  ')',
#  ',',
#  'sunflowerseed',
#  'cake',
#  'and',
#  'expellers',
#  '103',
#  '(',
#  '102',
#  ')',
#  ',',
#  'pellets',
#  '101',
#  '(',
#  '100',
#  ')',
#  ',',
#  'meal',
#  '99',
#  '(',
#  '98',
#  ')',
#  ',',
#  'linseed',
#  'oil',
#  '274',
#  '(',
#  '264',
#  ')',
#  ',',
#  'groundnutseed',
#  'oil',
#  '450',
#  '(',
#  '445',
#  ')',
#  ',',
#  'soybean',
#  'oil',
#  '300',
#  '(',
#  '290',
#  ')',
#  ',',
#  'rapeseed',
#  'oil',
#  '290',
#  '(',
#  '280',
#  ')',
#  '.',
#  'Sunflowerseed',
#  'oil',
#  'for',
#  'shipment',
#  'through',
#  'May',
#  '323',
#  '(',
#  '313',
#  ')',
#  'and',
#  'june',
#  'onwards',
#  '330',
#  '(',
#  '320',
#  ')',
#  '.',
#  'The',
#  'board',
#  'also',
#  'adjusted',
#  'export',
#  'prices',
#  'at',
#  'which',
#  'export',
#  'taxes',
#  'are',
#  'levied',
#  'in',
#  'dlrs',
#  'per',
#  'tonne',
#  'FOB',
#  ',',
#  'previous',
#  'in',
#  'brackets',
#  ',',
#  'as',
#  'follows',
#  ':',
#  'Bran',
#  'pollard',
#  'wheat',
#  '40',
#  '(',
#  '42',
#  ')',
#  ',',
#  'pellets',
#  '42',
#  '(',
#  '44',
#  ')',
#  '.']

# %%
for sent in sent_tokenize(rawtext):
    print(word_tokenize(sent))
# Out:
# ['RPT', '-', 'ARGENTINE', 'GRAIN/OILSEED', 'EXPORT', 'PRICES', 'ADJUSTED', 'The', 'Argentine', 'Grain', 'Board', 'adjusted', 'minimum', 'export', 'prices', 'of', 'grain', 'and', 'oilseed', 'products', 'in', 'dlrs', 'per', 'tonne', 'FOB', ',', 'previous', 'in', 'brackets', ',', 'as', 'follows', ':', 'Sorghum', '64', '(', '63', ')', ',', 'sunflowerseed', 'cake', 'and', 'expellers', '103', '(', '102', ')', ',', 'pellets', '101', '(', '100', ')', ',', 'meal', '99', '(', '98', ')', ',', 'linseed', 'oil', '274', '(', '264', ')', ',', 'groundnutseed', 'oil', '450', '(', '445', ')', ',', 'soybean', 'oil', '300', '(', '290', ')', ',', 'rapeseed', 'oil', '290', '(', '280', ')', '.']
# ['Sunflowerseed', 'oil', 'for', 'shipment', 'through', 'May', '323', '(', '313', ')', 'and', 'june', 'onwards', '330', '(', '320', ')', '.']
# ['The', 'board', 'also', 'adjusted', 'export', 'prices', 'at', 'which', 'export', 'taxes', 'are', 'levied', 'in', 'dlrs', 'per', 'tonne', 'FOB', ',', 'previous', 'in', 'brackets', ',', 'as', 'follows', ':', 'Bran', 'pollard', 'wheat', '40', '(', '42', ')', ',', 'pellets', '42', '(', '44', ')', '.']

# %%
for sent in sent_tokenize(rawtext):
    print([word.lower() for word in word_tokenize(sent)])
# Out:
# ['rpt', '-', 'argentine', 'grain/oilseed', 'export', 'prices', 'adjusted', 'the', 'argentine', 'grain', 'board', 'adjusted', 'minimum', 'export', 'prices', 'of', 'grain', 'and', 'oilseed', 'products', 'in', 'dlrs', 'per', 'tonne', 'fob', ',', 'previous', 'in', 'brackets', ',', 'as', 'follows', ':', 'sorghum', '64', '(', '63', ')', ',', 'sunflowerseed', 'cake', 'and', 'expellers', '103', '(', '102', ')', ',', 'pellets', '101', '(', '100', ')', ',', 'meal', '99', '(', '98', ')', ',', 'linseed', 'oil', '274', '(', '264', ')', ',', 'groundnutseed', 'oil', '450', '(', '445', ')', ',', 'soybean', 'oil', '300', '(', '290', ')', ',', 'rapeseed', 'oil', '290', '(', '280', ')', '.']
# ['sunflowerseed', 'oil', 'for', 'shipment', 'through', 'may', '323', '(', '313', ')', 'and', 'june', 'onwards', '330', '(', '320', ')', '.']
# ['the', 'board', 'also', 'adjusted', 'export', 'prices', 'at', 'which', 'export', 'taxes', 'are', 'levied', 'in', 'dlrs', 'per', 'tonne', 'fob', ',', 'previous', 'in', 'brackets', ',', 'as', 'follows', ':', 'bran', 'pollard', 'wheat', '40', '(', '42', ')', ',', 'pellets', '42', '(', '44', ')', '.']

# %%
from nltk.corpus import stopwords

stopwords_en = stopwords.words('english')
print(stopwords_en)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
EN_Stopwords = set(stopwords.words('english')) # Set checking is faster in Python than list.

# Tokenize and lowercase
tokenized_lowercase = list(map(str.lower, word_tokenize(rawtext)))

stopwords_english = set(stopwords.words('english')) # Set checking is faster in Python than list.

# List comprehension.
print([word for word in tokenized_lowercase if word not in stopwords_en])
# Out:
# ['rpt', '-', 'argentine', 'grain/oilseed', 'export', 'prices', 'adjusted', 'argentine', 'grain', 'board', 'adjusted', 'minimum', 'export', 'prices', 'grain', 'oilseed', 'products', 'dlrs', 'per', 'tonne', 'fob', ',', 'previous', 'brackets', ',', 'follows', ':', 'sorghum', '64', '(', '63', ')', ',', 'sunflowerseed', 'cake', 'expellers', '103', '(', '102', ')', ',', 'pellets', '101', '(', '100', ')', ',', 'meal', '99', '(', '98', ')', ',', 'linseed', 'oil', '274', '(', '264', ')', ',', 'groundnutseed', 'oil', '450', '(', '445', ')', ',', 'soybean', 'oil', '300', '(', '290', ')', ',', 'rapeseed', 'oil', '290', '(', '280', ')', '.', 'sunflowerseed', 'oil', 'shipment', 'may', '323', '(', '313', ')', 'june', 'onwards', '330', '(', '320', ')', '.', 'board', 'also', 'adjusted', 'export', 'prices', 'export', 'taxes', 'levied', 'dlrs', 'per', 'tonne', 'fob', ',', 'previous', 'brackets', ',', 'follows', ':', 'bran', 'pollard', 'wheat', '40', '(', '42', ')', ',', 'pellets', '42', '(', '44', ')', '.']

# %%
EN_Stopwords = set(stopwords.words('english')) # Set checking is faster in Python than list.

# Tokenize and lowercase
tokenized_lowercase = list(map(str.lower, word_tokenize(rawtext)))

stopwords_english = set(stopwords.words('english')) # Set checking is faster in Python than list.

# List comprehension.
print([word for word in tokenized_lowercase if word not in stopwords_en])
# Out:
# ['rpt', '-', 'argentine', 'grain/oilseed', 'export', 'prices', 'adjusted', 'argentine', 'grain', 'board', 'adjusted', 'minimum', 'export', 'prices', 'grain', 'oilseed', 'products', 'dlrs', 'per', 'tonne', 'fob', ',', 'previous', 'brackets', ',', 'follows', ':', 'sorghum', '64', '(', '63', ')', ',', 'sunflowerseed', 'cake', 'expellers', '103', '(', '102', ')', ',', 'pellets', '101', '(', '100', ')', ',', 'meal', '99', '(', '98', ')', ',', 'linseed', 'oil', '274', '(', '264', ')', ',', 'groundnutseed', 'oil', '450', '(', '445', ')', ',', 'soybean', 'oil', '300', '(', '290', ')', ',', 'rapeseed', 'oil', '290', '(', '280', ')', '.', 'sunflowerseed', 'oil', 'shipment', 'may', '323', '(', '313', ')', 'june', 'onwards', '330', '(', '320', ')', '.', 'board', 'also', 'adjusted', 'export', 'prices', 'export', 'taxes', 'levied', 'dlrs', 'per', 'tonne', 'fob', ',', 'previous', 'brackets', ',', 'follows', ':', 'bran', 'pollard', 'wheat', '40', '(', '42', ')', ',', 'pellets', '42', '(', '44', ')', '.']

# %%
from string import punctuation

# It's a string so we have to them into a set type
print('From string.punctuation:', type(punctuation), punctuation)

punct_stopwords = stopwords_english.union(set(punctuation))
print(punct_stopwords)
# Out:
# From string.punctuation: <class 'str'> !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# {'|', 'your', 'further', 'or', "she's", 'was', "it's", 'them', 'this', "didn't", 'hadn', 'did', '(', 'we', 'between', 'our', ',', 'am', 'both', 'to', 'on', "needn't", 'wouldn', 'theirs', 'below', 'from', 'where', 'once', 't', 'ma', 'yourselves', '@', "wasn't", "shouldn't", 'when', '+', '?', 'had', "that'll", 'shouldn', '/', 'they', 'don', 'own', 'off', 'ain', 'other', "you're", 'should', 'nor', 'through', "won't", 'd', 'herself', 'down', 'can', 'if', '^', "wouldn't", 'doing', 'not', '$', '<', 'were', "haven't", "doesn't", ')', 'most', "aren't", 'ours', 'out', 'itself', "shan't", 'few', "you've", "should've", "don't", 'is', 'by', 'here', 'above', 're', 'aren', 'mightn', 'a', 'won', '}', "isn't", 'that', 'are', 'more', 'wasn', 'against', "weren't", '>', 'you', ';', "hasn't", "you'd", '{', 'have', 'any', 'do', 'some', 'with', 'ourselves', 'all', 'being', 'my', 've', 'whom', 'about', 'has', '&', 'an', 'does', 'such', "mustn't", 'how', 'themselves', 'as', 'at', '.', 'needn', 'for', '!', "you'll", 'yourself', "couldn't", 'these', 'those', 'be', 'only', 'now', 'under', 'hasn', 'their', 'she', 'hers', 'because', '#', 'yours', 'didn', 'each', 'in', '%', "hadn't", 'same', 'having', ']', 'i', 'shan', 'the', 'haven', 'again', 'into', 'he', 's', 'just', 'isn', 'so', '=', "'", 'been', 'of', '_', 'why', 'mustn', 'o', 'y', 'her', ':', 'and', 'after', 'll', 'myself', 'before', 'there', "mightn't", '-', 'until', 'but', 'who', 'while', 'too', '*', 'his', 'weren', 'doesn', 'which', 'its', '~', 'couldn', '"', '[', 'me', 'than', 'him', 'no', 'up', 'will', 'm', '`', 'over', 'himself', 'very', 'then', 'during', 'it', '\\', 'what'}

# %%
punch_stop_word= [word for word in tokenized_lowercase if word not in punct_stopwords]

print(punch_stop_word)
# Out:
# ['rpt', 'argentine', 'grain/oilseed', 'export', 'prices', 'adjusted', 'argentine', 'grain', 'board', 'adjusted', 'minimum', 'export', 'prices', 'grain', 'oilseed', 'products', 'dlrs', 'per', 'tonne', 'fob', 'previous', 'brackets', 'follows', 'sorghum', '64', '63', 'sunflowerseed', 'cake', 'expellers', '103', '102', 'pellets', '101', '100', 'meal', '99', '98', 'linseed', 'oil', '274', '264', 'groundnutseed', 'oil', '450', '445', 'soybean', 'oil', '300', '290', 'rapeseed', 'oil', '290', '280', 'sunflowerseed', 'oil', 'shipment', 'may', '323', '313', 'june', 'onwards', '330', '320', 'board', 'also', 'adjusted', 'export', 'prices', 'export', 'taxes', 'levied', 'dlrs', 'per', 'tonne', 'fob', 'previous', 'brackets', 'follows', 'bran', 'pollard', 'wheat', '40', '42', 'pellets', '42', '44']

# %%
from nltk.stem import PorterStemmer

# %%
porter = PorterStemmer()

for word in ['Talking', 'Talks', 'Talked']:
    print(porter.stem(word))
# Out:
# talk
# talk
# talk

# %%
import nltk
nltk.download('wordnet')

from nltk.stem import WordNetLemmatizer

wnl = WordNetLemmatizer()

for word in ['Talking', 'Talks', 'Talked']:
    print(wnl.lemmatize(word))
# Out:
# Talking
# Talks
# Talked
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from nltk import pos_tag


wnl = WordNetLemmatizer()

def penn2morphy(penntag):
    """ Converts Penn Treebank tags to WordNet. """
    morphy_tag = {'NN':'n', 'JJ':'a',
                  'VB':'v', 'RB':'r'}
    try:
        return morphy_tag[penntag[:2]]
    except:
        return 'n'

# %%
pos_tagged_sent = pos_tag(word_tokenize('Prisha is learning maths online'))
print(pos_tagged_sent)
# Out:
# [('Prisha', 'NNP'), ('is', 'VBZ'), ('learning', 'VBG'), ('maths', 'NNS'), ('online', 'NN')]

# %%
def lemmatize_sent(text): 
    # Text input is string, returns lowercased strings.
    return[wnl.lemmatize(word.lower(), pos=penn2morphy(tag)) 
            for word, tag in pos_tag(word_tokenize(text))]

lemmatize_sent('Prisha is learning maths online')
# Out:
# ['prisha', 'be', 'learn', 'math', 'online']

# %%
print('Raw Text Before Lemmatization ')
print(rawtext, '\n')
print('Raw Text After Stop word Removal & Lemmaztization \n')
print([word for word in lemmatize_sent(rawtext) 
       if word not in stopwords_english
       and not word.isdigit() ])
# Out:
# Raw Text Before Lemmatization
# RPT - ARGENTINE GRAIN/OILSEED EXPORT PRICES ADJUSTED
#   The Argentine Grain Board adjusted
#   minimum export prices of grain and oilseed products in dlrs per
#   tonne FOB, previous in brackets, as follows:
#       Sorghum 64 (63), sunflowerseed cake and expellers 103 (102)
#   , pellets 101 (100), meal 99 (98), linseed oil 274 (264),
#   groundnutseed oil 450 (445), soybean oil 300 (290), rapeseed
#   oil 290 (280).
#       Sunflowerseed oil for shipment through May 323 (313) and
#   june onwards 330 (320).
#       The board also adjusted export prices at which export taxes
#   are levied in dlrs per tonne FOB, previous in brackets, as
#   follows:
#       Bran pollard wheat 40 (42), pellets 42 (44).
#
# Raw Text After Stop word Removal & Lemmaztization
#
# ['rpt', '-', 'argentine', 'grain/oilseed', 'export', 'price', 'adjusted', 'argentine', 'grain', 'board', 'adjust', 'minimum', 'export', 'price', 'grain', 'oilseed', 'product', 'dlrs', 'per', 'tonne', 'fob', ',', 'previous', 'bracket', ',', 'follow', ':', 'sorghum', '(', ')', ',', 'sunflowerseed', 'cake', 'expellers', '(', ')', ',', 'pellets', '(', ')', ',', 'meal', '(', ')', ',', 'linseed', 'oil', '(', ')', ',', 'groundnutseed', 'oil', '(', ')', ',', 'soybean', 'oil', '(', ')', ',', 'rapeseed', 'oil', '(', ')', '.', 'sunflowerseed', 'oil', 'shipment', 'may', '(', ')', 'june', 'onwards', '(', ')', '.', 'board', 'also', 'adjust', 'export', 'price', 'export', 'tax', 'levy', 'dlrs', 'per', 'tonne', 'fob', ',', 'previous', 'bracket', ',', 'follow', ':', 'bran', 'pollard', 'wheat', '(', ')', ',', 'pellets', '(', ')', '.']
